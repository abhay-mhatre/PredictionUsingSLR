# %% [markdown]
# <a href="https://colab.research.google.com/github/abhay-mhatre/TSF_GRIP_Internship/blob/Code-File/The_Sparks_Foundation_Task_3ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The Sparks Foundation - Task#3: Prediction using Decision Tree Algorithm
# * In this task we'll be using popular machine learning library Scikit-Learn.
# * The purpose of this task is to build a decision tree to predict Species.
# # Presented By: Abhay Mhatre

# %% [markdown]
# # Importing Libraries:

# %%
# basic libraries:
import pandas as pd
import numpy as np

# plotting and visualization:
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.figsize'] = [15, 8]

# to suppress warnings
import warnings
warnings.filterwarnings('ignore')
# We'll import other required libraries as and when we require them.

# %% [markdown]
# # Loading Dataset:

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/abhay-mhatre/TSF_GRIP_Internship/main/Iris.csv')
df1.sample(10)
# Out:
#     Id  SepalLengthCm  ...  PetalWidthCm          Species
# 47  48            4.6  ...           0.2      Iris-setosa
# 78  79            6.0  ...           1.5  Iris-versicolor
# 51  52            6.4  ...           1.5  Iris-versicolor
# 93  94            5.0  ...           1.0  Iris-versicolor
# 69  70            5.6  ...           1.1  Iris-versicolor
# 48  49            5.3  ...           0.2      Iris-setosa
# 6    7            4.6  ...           0.3      Iris-setosa
# 34  35            4.9  ...           0.1      Iris-setosa
# 94  95            5.6  ...           1.3  Iris-versicolor
# 81  82            5.5  ...           1.0  Iris-versicolor
#
# [10 rows x 6 columns]

# %% [markdown]
# # Basic EDA:

# %%
sns.distplot(df1['SepalLengthCm'])
plt.title("Sepal Length in CM")
plt.show()

# %%
sns.distplot(df1['SepalWidthCm'])
plt.title("Sepal Width in CM")
plt.show()

# %%
sns.distplot(df1['PetalLengthCm'])
plt.title("Petal Length in CM")
plt.show()

# %%
sns.distplot(df1['PetalWidthCm'])
plt.title("Petal Width in CM")
plt.show()

# %% [markdown]
# # Preparing Data:

# %%
X = df1.drop(columns = ['Id', 'Species'])
y = df1['Species']

# %% [markdown]
# # Building Decision Tree Model:

# %%
# importing library:
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier()
dtc.fit(X, y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# # Visualising Decision Tree:

# %%
from io import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# Visualize the graph
dot_data = StringIO()
export_graphviz(dtc, out_file=dot_data, feature_names=labels,  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())

# %%
Image(graph.create_png())

# %% [markdown]
# * We can pass any test set to predict the values.
